# %% [markdown]
# <h3><b>We will see about Data types</b></h3>

# %% [markdown]
# Comments

# %%
# this is the first comment
spam = 1  # and this is the variable declaration
          # ... and now a third!
a = "# This is not a comment because it's inside quotes."

# %%
print(a)
# Out:
# # This is not a comment because it's inside quotes.

# %%
name = input("What’s your name? ") 
print("Hello", name)
# Out:
# What’s your name? Sreeja
# Hello Sreeja

# %%
val = input("Enter any value between 1 and 100: ")
print(f'The entered number is {val} and its type is {type(val)}')
# Out:
# Enter any value between 1 and 100: hgfhfjh
# The entered number is hgfhfjh and its type is <class 'str'>

# %%
number = 3
print(number, type(number))
print(number + 42)
# Out:
# 3 <class 'int'>
# 45

# %%
number = '3'
print(number, type(number))
print(number + "Python")
# Out:
# 3 <class 'str'>
# 3Python

# %%
number
a = 1

b = True
c = 1e0
d = 1 + 0j
print(type(number),type(a), type(c), type(d), type(b))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'complex'> <class 'bool'>

# %%
d.conjugate()
# Out:
# 0.0

# %%
2 + 2
# Out:
# 4

# %%
50 - 5*6
# Out:
# 20

# %%
(50 - 5*6) // 4
# Out:
# 5.0

# %%
8 // 5  # division always returns a floating point number
# Out:
# 1

# %% [markdown]
# <b>Division (/) always returns a float. To do floor division and get an integer result (discarding any fractional result) you can use the // operator; to calculate the remainder you can use %:</b>

# %%
17 % 3
# Out:
# 2

# %% [markdown]
# <b>With Python, it is possible to use the ** operator to calculate powers 1:</b>

# %%
10 ** 3
# Out:
# 1000

# %%
divmod(10,6)
# Out:
# (1, 4)

# %%
d = 1 + 0j
d.conjugate()
# Out:
# (1-0j)

# %% [markdown]
# Bitwise Operator

# %%
a = 7
b = 2
print(bin(a), bin(b))

a & b # a |b a^b ~a
~a
a >> 1
# Out:
# 0b111 0b10
# 3

# %% [markdown]
# **STRINGS**

# %% [markdown]
# Besides numbers, Python can also manipulate strings, which can be expressed in several ways. They can be enclosed in single quotes ('...') or double quotes ("...") with the same result

# %%
s = "hello ... world"
print(s)

s = 'hello world'
print(s)
# Out:
# hello ... world
# hello world

# %%
print("sp\nam")
# Out:
# sp
# am

# %% [markdown]
# If you don’t want characters prefaced by \ to be interpreted as special characters, you can use raw strings by adding an r before the first quote:

# %%
print(r"sp\tam") # or: print("sp\\nam")

print("sp\\nam")

print('C:\some\name')  
print(r'C:\some\name')
# Out:
# sp\tam
# sp\nam
# C:\some
# ame
# C:\some\name

# %%
str1 = r"text is \n printed"
print(str1)
# Out:
# text is \n printed

# %% [markdown]
# String literals can span multiple lines. One way is using triple-quotes: """...""" or '''...'''.

# %%
print("""
S
A
T
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
""")
# Out:
# S
# A
# T
# Usage: thingy [OPTIONS]
#      -h                        Display this usage message
#      -H hostname               Hostname to connect to

# %%
"""
S
A
T
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
"""
# Out:
# '\nS\nA\nT\nUsage: thingy [OPTIONS]\n     -h                        Display this usage message\n     -H hostname               Hostname to connect to\n'

# %%
x = 1.0
print(type(x))
print(int(x))
type(x)
x= str(x)
type(x)
# Out:
# <class 'float'>
# 1
# str

# %%
print(str(x))
# Out:
# 1.0

# %%
a = str(x)
type(a)
a
# Out:
# str

# %% [markdown]
# Strings can be concatenated (glued together) with the + operator, and repeated with *:

# %%
3 * 'un' + 'ium'
# Out:
# 'unununium'

# %%
prefix = 'Py123'
prefix + 'thon'
# Out:
# 'Py123thon'
