# %% [markdown]
# # 🐍 01- Assignment on Basics
#
# This notebook contains practice questions on **Data Types, String Methods, List Methods, and Control Statements**.

# %% [markdown]
# ## 1️⃣ Data Types Questions
#
# 1. What is the type of the following values?
#    - `10`
#    - `3.14`
#    - `'Hello'`
#    - `True`
#    - `[1, 2, 3]`
#    - `(1, 2, 3)`
#    - `{'a': 1, 'b': 2}`
#    - `{1, 2, 3}`
#
# 2. Convert the integer `45` into a float and a string.
#
# 3. Check whether the variable `x = 10` is an instance of `int`.
#
# 4. Swap two variables without using a third variable.

# %% [markdown]
# ## 1️⃣ Answers

# %%
#Answer 2

# %% [markdown]
# ## 2️⃣ String Methods Questions
#
# 1. Given `s = " Python Programming "`:
#    - Remove spaces from both ends.
#    - Convert to uppercase.
#    - Replace "Python" with "Java".
#    - Check if the string starts with "Py".
#
# 2. Reverse the string `"hello"` using slicing.
#
# 3. Count the number of occurrences of the letter `'a'` in `"banana"`.
#
# 4. Split the string `"apple,banana,mango"` into a list.

# %% [markdown]
# ## 2️⃣ Answers

# %% [markdown]
# ## 3️⃣ List Methods Questions
#
# 1. Create a list of 5 numbers. Perform:
#    - Append an element.
#    - Insert an element at index 2.
#    - Remove an element.
#    - Sort the list in ascending order.
#    - Reverse the list.
#
# 2. Combine two lists: `[1,2,3]` and `[4,5,6]`.
#
# 3. Find the maximum and minimum values in a list.
#
# 4. Count how many times `3` appears in `[1,3,5,3,7,3]`.

# %% [markdown]
# ## 3️⃣ Answers

# %% [markdown]
# ## 4️⃣ Control Statements Questions
#
# 1. Write a program to check whether a number is positive, negative, or zero.
#
# 2. Print numbers from 1 to 10 using a `for` loop.
#
# 3. Print even numbers from 1 to 20 using a `while` loop.
#
# 4. Write a program to find the sum of numbers from 1 to 50.
#
# 5. Create a simple grading system:
#    - If marks >= 90: Grade A
#    - If marks >= 75: Grade B
#    - If marks >= 50: Grade C
#    - Else: Fail

# %% [markdown]
# ##  4️⃣ Answers
